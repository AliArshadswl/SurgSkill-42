# %%
# Detailed breakdown (includes sub-categories, question types, answer types)
# !python check_classes_1.py \
    --train /mnt/share/ali/VLM_Project/hospital_data/train.json \
    --test /mnt/share/ali/VLM_Project/hospital_data/test.json \
    --detailed
# Out:
# ...
# LOADING DATASETS
# ...
# ✅ Loaded 1516 training samples from /mnt/share/ali/VLM_Project/hospital_data/train.json
# ✅ Loaded 448 test samples from /mnt/share/ali/VLM_Project/hospital_data/test.json
#
# ...
# DATASET: TRAIN
# ...
# Total samples: 1516
# Samples with frames: 1516
# Frames per sample: min=8, max=8, avg=8.0
# Unique answers: 40
#
# ...
# CATEGORY DISTRIBUTION (TRAIN)
# ...
# Category                                      Count      Percentage
# ----------------------------------------------------------------------
# full_description                                379           25.0%
# completion_status                               379           25.0%
# step_classification                             379           25.0%
# stage_classification                            379           25.0%
# ----------------------------------------------------------------------
# TOTAL                                          1516          100.0%
#
# ...
# SUB-CATEGORY DISTRIBUTION (TRAIN)
# ...
