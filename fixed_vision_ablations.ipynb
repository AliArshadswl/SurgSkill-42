# %%
# !python convert_to_safetensors.py /mnt/share/ali/Model_testing/models/eva-clip-8b/baai/EVA-CLIP-8B/
# Out:
# Found 5 .bin files to convert
# PyTorch version: 2.5.1+cu121
# Converting pytorch_model-00001-of-00004.bin... ✓ -> pytorch_model-00001-of-00004.safetensors
# Converting pytorch_model-00002-of-00004.bin... ✓ -> pytorch_model-00002-of-00004.safetensors
# Converting pytorch_model-00004-of-00004.bin... ✓ -> pytorch_model-00004-of-00004.safetensors
# Converting EVA_8B_psz14.bin... ✓ -> EVA_8B_psz14.safetensors
# Converting pytorch_model-00003-of-00004.bin... ✓ -> pytorch_model-00003-of-00004.safetensors
#
# ...
# CONVERSION SUMMARY
# ...
# Successfully converted: 5
# Failed: 0
#
# Note: You may need to create a model.safetensors.index.json file
#       based on pytorch_model.bin.index.json

# %%
# !CUDA_VISIBLE_DEVICES=1 python vision_ablations_fixed.py --encoders sam_vit_base sam2_hiera_large clip_large dinov2_large siglip_base
# Out:
# 2026-01-13 13:40:43 | INFO     | ======================================================================
# 2026-01-13 13:40:43 | INFO     | VISION ENCODER ABLATION STUDY
# 2026-01-13 13:40:43 | INFO     | ======================================================================
# 2026-01-13 13:40:43 | INFO     | Encoders to test: ['sam_vit_base', 'sam2_hiera_large', 'clip_large', 'dinov2_large', 'siglip_base']
# 2026-01-13 13:40:43 | INFO     | ======================================================================
# 2026-01-13 13:40:43 | INFO     | Using device: cuda
# 2026-01-13 13:40:43 | INFO     | GPU: NVIDIA H800 PCIe
# 2026-01-13 13:40:43 | INFO     | GPU Memory: {'allocated_gb': 0.0, 'reserved_gb': 0.0, 'total_gb': 79.11, 'free_gb': 79.11}
# 2026-01-13 13:40:43 | INFO     | ======================================================================
# 2026-01-13 13:40:43 | INFO     | LOADING DATA
# ...

# %%
# !CUDA_VISIBLE_DEVICES=1 python vision_ablations_fix.py --encoders  siglip_base
# Out:
# 2026-01-14 16:44:28 | INFO     | ======================================================================
# 2026-01-14 16:44:28 | INFO     | VISION ENCODER ABLATION STUDY
# 2026-01-14 16:44:28 | INFO     | ======================================================================
# 2026-01-14 16:44:28 | INFO     | Encoders to test: ['siglip_base']
# 2026-01-14 16:44:28 | INFO     | ======================================================================
# 2026-01-14 16:44:28 | INFO     | Using device: cuda
# 2026-01-14 16:44:28 | INFO     | GPU: NVIDIA H800 PCIe
# 2026-01-14 16:44:28 | INFO     | GPU Memory: {'allocated_gb': 0.0, 'reserved_gb': 0.0, 'total_gb': 79.11, 'free_gb': 79.11}
# 2026-01-14 16:44:28 | INFO     | ======================================================================
# 2026-01-14 16:44:28 | INFO     | LOADING DATA
# 2026-01-14 16:44:28 | INFO     | ======================================================================
# ...

# %%
# !CUDA_VISIBLE_DEVICES=1 python vision_ablations_fix.py --encoders  siglip_base
# Out:
# 2026-01-14 17:31:17 | INFO     | ======================================================================
# 2026-01-14 17:31:17 | INFO     | VISION ENCODER ABLATION STUDY
# 2026-01-14 17:31:17 | INFO     | ======================================================================
# 2026-01-14 17:31:17 | INFO     | Encoders to test: ['siglip_base']
# 2026-01-14 17:31:17 | INFO     | ======================================================================
# 2026-01-14 17:31:17 | INFO     | Using device: cuda
# 2026-01-14 17:31:17 | INFO     | GPU: NVIDIA H800 PCIe
# 2026-01-14 17:31:17 | INFO     | GPU Memory: {'allocated_gb': 0.0, 'reserved_gb': 0.0, 'total_gb': 79.11, 'free_gb': 79.11}
# 2026-01-14 17:31:17 | INFO     | ======================================================================
# 2026-01-14 17:31:17 | INFO     | LOADING DATA
# 2026-01-14 17:31:17 | INFO     | ======================================================================
# ...

# %%
# %%bash
# for run in 1 2 3; do
#   echo "================ RUN ${run} ================"
#   CUDA_VISIBLE_DEVICES=1 python vision_ablations_fix.py \
#     --encoders siglip_base
# done
# Out:
# ================ RUN 1 ================
# 2026-01-14 18:21:29 | INFO     | ======================================================================
# 2026-01-14 18:21:29 | INFO     | VISION ENCODER ABLATION STUDY
# 2026-01-14 18:21:29 | INFO     | ======================================================================
# 2026-01-14 18:21:29 | INFO     | Encoders to test: ['siglip_base']
# 2026-01-14 18:21:29 | INFO     | ======================================================================
# 2026-01-14 18:21:29 | INFO     | Using device: cuda
# 2026-01-14 18:21:29 | INFO     | GPU: NVIDIA H800 PCIe
# 2026-01-14 18:21:29 | INFO     | GPU Memory: {'allocated_gb': 0.0, 'reserved_gb': 0.0, 'total_gb': 79.11, 'free_gb': 79.11}
# 2026-01-14 18:21:29 | INFO     | ======================================================================
# 2026-01-14 18:21:29 | INFO     | LOADING DATA
# 2026-01-14 18:21:29 | INFO     | ======================================================================
# ...
