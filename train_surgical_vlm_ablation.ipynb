# %%
# Visual Tokens Ablation
# !CUDA_VISIBLE_DEVICES=1 python train_surgical_vlm_ablation.py \
    --ablation visual_tokens \
    --ablation_values 3 5 7 10 14 28 \
    --epochs 10
# Out:
# 2026-01-09 00:31:11,315 - INFO - ======================================================================
# 2026-01-09 00:31:11,315 - INFO - ABLATION STUDY: visual_tokens
# 2026-01-09 00:31:11,315 - INFO - Values to test: [3, 5, 7, 10, 14, 28]
# 2026-01-09 00:31:11,315 - INFO - ======================================================================
# 2026-01-09 00:31:11,315 - INFO -
# ...
# 2026-01-09 00:31:11,315 - INFO - Testing visual_tokens = 3
# 2026-01-09 00:31:11,315 - INFO - ==================================================
# 2026-01-09 00:31:11,373 - INFO - Device: cuda
# 2026-01-09 00:31:11,541 - INFO - Loading tokenizer: /mnt/share/ali/VLMs/hf_cache/hub/Qwen3-0.6B/
# 2026-01-09 00:31:11,839 - INFO - Added 4 task tokens, vocab size: 151673
# 2026-01-09 00:31:11,839 - INFO - Using dtype: torch.bfloat16
# 2026-01-09 00:31:11,840 - INFO - Loading LLM with 4-bit quantization...
# ...

# %%
# Number of Frames Ablation
python train_surgical_vlm_ablation.py \
    --ablation num_frames \
    --ablation_values 1 2 4 8 \
    --epochs 10

# %%
# LoRA Rank Ablation
python train_surgical_vlm_ablation.py \
    --ablation lora_r \
    --ablation_values 8 16 32 64 \
    --epochs 10

# %%
# Learning Rate Ablation
python train_surgical_vlm_ablation.py \
    --ablation learning_rate \
    --ablation_values 1e-4 2e-4 5e-4 1e-3 \
    --epochs 10
